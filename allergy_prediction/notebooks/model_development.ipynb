# %% [markdown]
# # **Tensorflow/Keras model development**
#
# Here we will process our data to develop a model that can predict peanut allergy incidence from categorical features provided.
#
# The model will be built using Tensorflow and Keras.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Import data**

# %%
X_train = pd.read_csv('/content/drive/MyDrive/Projects/allergy_prediction/data/X_train_resampled.csv')
y_train = pd.read_csv('/content/drive/MyDrive/Projects/allergy_prediction/data/y_train_resampled.csv')
X_test = pd.read_csv('/content/drive/MyDrive/Projects/allergy_prediction/data/X_test_encoded.csv')
y_test = pd.read_csv('/content/drive/MyDrive/Projects/allergy_prediction/data/y_test.csv')

# %% [markdown]
# **Design model**

# %%
model = Sequential()

# %%
# Input layer
model.add(Dense(64, activation='relu'))

# Hidden layers
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(16, activation='relu'))

# Output layer (binary classification)
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Train model**

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 31s 2ms/step - accuracy: 0.6334 - loss: 0.6336 - val_accuracy: 0.0477 - val_loss: 0.9059
# Epoch 2/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step - accuracy: 0.6329 - loss: 0.6348 - val_accuracy: 0.0478 - val_loss: 0.9138
# Epoch 3/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 30s 2ms/step - accuracy: 0.6312 - loss: 0.6345 - val_accuracy: 0.0477 - val_loss: 0.9161
# Epoch 4/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.6322 - loss: 0.6339 - val_accuracy: 0.0476 - val_loss: 0.9010
# Epoch 5/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.6327 - loss: 0.6341 - val_accuracy: 0.0477 - val_loss: 0.8897
# Epoch 6/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.6324 - loss: 0.6338 - val_accuracy: 0.0478 - val_loss: 0.8969
# Epoch 7/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 30s 2ms/step - accuracy: 0.6324 - loss: 0.6333 - val_accuracy: 0.0477 - val_loss: 0.9064
# Epoch 8/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 31s 2ms/step - accuracy: 0.6314 - loss: 0.6345 - val_accuracy: 0.0499 - val_loss: 0.9024
# Epoch 9/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.6331 - loss: 0.6341 - val_accuracy: 0.0477 - val_loss: 0.9153
# Epoch 10/10
# 12982/12982 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step - accuracy: 0.6310 - loss: 0.6349 - val_accuracy: 0.0477 - val_loss: 0.8871

# %% [markdown]
# **Evaluate on the held out test set**

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 2083/2083 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9595 - loss: 0.4975
# Test Loss: 0.4989
# Test Accuracy: 0.9590

# %% [markdown]
# Achieved c.96% accuracy.
